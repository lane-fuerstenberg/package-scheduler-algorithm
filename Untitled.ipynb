# %%
import main
# Out:
#                                                                                         Unnamed: 1  \
# NaN                                                                                            NaN
# NaN                                                                                            NaN
# WGUPS Distance Table                                                          WGUPS Distance Table
# NaN                                                                                            NaN
# NaN                                                                                            NaN
# NaN                                                                                            NaN
# NaN                                                                                            NaN
#  HUB                                                                                           HUB
# ...

# %%
from IPython.display import display
import numpy as np

# %%
display(main.distance_data)
# Out:
#                                                                                              NaN  \
#  HUB                                                                                         HUB
#  1060 Dalton Ave S(84104)                                             1060 Dalton Ave S\n(84104)
#  1330 2100 S(84106)                                                         1330 2100 S\n(84106)
#  1488 4800 S(84123)                                                         1488 4800 S\n(84123)
#  177 W Price Ave(84115)                                                 177 W Price Ave\n(84115)
#  195 W Oakland Ave(84115)                                             195 W Oakland Ave\n(84115)
#  2010 W 500 S(84104)                                                       2010 W 500 S\n(84104)
#  2300 Parkway Blvd(84119)                                             2300 Parkway Blvd\n(84119)
#  233 Canyon Rd(84103)                                                     233 Canyon Rd\n(84103)
# ...

# %%
main.distance_data = main.distance_data.drop(main.distance_data[:6].index)
# Out:
#                                            Unnamed: 0  \
# 25      Utah DMV Administrative Office\n 380 W 2880 S
# 26     Third District Juvenile Court\n 410 S State St
# 27  Cottonwood Regional Softball Complex\n 4300 S ...
# 28                Holiday City Office\n 4580 S 2300 E
# 29                 Murray City Museum\n 5025 State St
# 30  Valley Regional Softball Complex\n 5100 South ...
# 31  City Center of Rock Springs\n 5383 South 900 E...
# 32       Rice Terrace Pavilion Park\n 600 E 900 South
# 33       Wheeler Historic Farm \n 6351 South 900 East
#
#                         Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 25           380 W 2880 S\n(84115)        3.6          5        3.6
# 26         410 S State St\n(84111)        6.5        4.8        4.3
# 27          4300 S 1300 E\n(84117)        1.9        9.5        3.3
# 28          4580 S 2300 E\n(84117)        3.4       10.9          5
# 29          5025 State St\n(84107)        2.4        8.3        6.1
# ...

# %%
main.distance_data.rename(index=main.distance_data['Unnamed: 1']))
main.distance_data = main.distance_data.drop('Unnamed: 0', axis=0)

main.distance_data
# Out:
#                                                                                          Unnamed: 0  \
# NaN                                                                                             NaN
# NaN                                                                                             NaN
# WGUPS Distance Table                                                                            NaN
# NaN                                                                                             NaN
# NaN                                                                                             NaN
# NaN                                                                                             NaN
# NaN                                                                  DISTANCE BETWEEN HUBS IN MILES
#  HUB                                              Western Governors University\n4001 South 700 E...
# ...

# %%
main.distance_data['Unnamed: 1']
# Out:
# 0                                                  NaN
# 1                                                  NaN
# 2                                 WGUPS Distance Table
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  HUB
# 8                           1060 Dalton Ave S\n(84104)
# 9                                 1330 2100 S\n(84106)
# 10                                1488 4800 S\n(84123)
# 11                            177 W Price Ave\n(84115)
# 12                          195 W Oakland Ave\n(84115)
# 13                               2010 W 500 S\n(84104)
# 14                          2300 Parkway Blvd\n(84119)
# 15                              233 Canyon Rd\n(84103)
# 16                               2530 S 500 E\n(84106)
# ...
